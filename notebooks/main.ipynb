# %% [markdown]
# <a href="https://colab.research.google.com/github/raaghavkk/UG04-NLP-COMM061/blob/main/notebooks/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # UG04 : BESSTIE Sequence Classification
#  **COMM061 NLP Coursework | Group UG04**
#
#  ## Notebook Structure
#
#  This is the main entry point for the UG04 coursework codebase.
#  Each experiment is contained in its own notebook as listed below.
#
#  | Section | Notebook | Owner |
#  |---------|----------|-------|
#  | Q1 — Data Analysis & Visualisation | `raaghav_data_analysis.ipynb` | Raaghav |
#  | Q2.1 — Baseline vs PTLM | `naeem_baselines.ipynb` | Naeem |
#  | Q2.2 — Inner vs Outer Circle | `raaghav_crossvariety.ipynb` | Raaghav |
#  | Q2.3 — Monolingual vs Multilingual | `akshyat_finetuning.ipynb` | Akshyat |
#  | Q3 — Evaluation | Contained within each notebook above | All |
#  | Q4 — Error Analysis | Contained within each notebook above | All |
#  | Q5 — Deployment | `deployment.ipynb` | Raaghav |
#
#
#  ## Setup
#  Install all dependencies before running individual notebooks.

# %%
# !pip install -r requirements.txt

# %% [markdown]
#  ## How to Run
#
#  1. Run this notebook first to install dependencies
#  2. Open and run each experiment notebook in the order listed above
#  3. All models are hosted on HuggingFace at raaghavkk/roberta-sarcasm-*
#  4. Dataset: surrey-nlp/BESSTIE-CW-26 (loaded automatically via HuggingFace datasets)
#
#  **Note:** Training notebooks require GPU. Use Google Colab with T4 or A100.
#  Deployment notebook (Q5) can be run on CPU.
